# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('planes.dat', encoding='utf-8', header=None)

# %%
df.columns = [
'Name',
'IATA',
'ICAO'
    ]

# %%
df = df.assign(Seats=pd.Series(np.random.randint(20, 300, size=df.shape[0])).values)
df = df.assign(Crew=pd.Series(np.random.randint(2, 19, size=df.shape[0])).values)
df = df.assign(Range=pd.Series(np.random.randint(1000, 16000, size=df.shape[0])).values)

# %%
filtered = df[(df.Name != '\N') & (df.IATA != '\N') & (pd.notnull(df.IATA))]

# %%
filtered
# Out:
#                                                Name IATA  ICAO  Seats  Crew  \
# 0      Aerospatiale (Sud Aviation) Se.210 Caravelle  CRV  S210    248     2
# 1                    Aerospatiale/Alenia ATR 42-300  AT4  AT43    149    13
# 2                    Aerospatiale/Alenia ATR 42-500  AT5  AT45    192    11
# 3                    Aerospatiale/Alenia ATR 42-600  ATR  AT46    158     2
# 4                        Aerospatiale/Alenia ATR 72  AT7  AT72    143    17
# 5                                       Airbus A300  AB3  A30B     85     2
# 6                                   Airbus A300-600  ABY  A306    170    16
# 7                                       Airbus A310  310  A310     76     4
# 8                                       Airbus A318  318  A318    126    11
# 9                                       Airbus A319  319  A319     62    18
# 10                                      Airbus A320  320  A320    226     6
# 11                                      Airbus A321  321  A321     65    10
# 12                                      Airbus A330  330    \N    162    13
# 13                                  Airbus A330-200  332  A332    263     2
# 14                                  Airbus A330-300  333  A333    225     7
# 15                                      Airbus A340  340    \N    124    13
# 16                                  Airbus A340-200  342  A342    287    11
# 17                                  Airbus A340-300  343  A343    211     4
# 18                                  Airbus A340-500  345  A345     64    12
# 19                                  Airbus A340-600  346  A346    232    18
# 20                                      Airbus A350  350    \N    101    15
# 21                                 Airbus A350-1000  351  A35K    127    15
# 22                                  Airbus A350-900  359  A359    219     3
# 23                                      Airbus A380  380    \N    179    11
# 24                                  Airbus A380-800  388  A388     63    14
# 25                                   Antonov An-148  A81  A148     23     8
# 26                                   Antonov An-158  A58  A158    180    11
# 27                                    Antonov AN-72  AN7  AN72     29     3
# 28                                       Avro RJ100  AR1  RJ1H    204     2
# 29                                        Avro RJ70  AR7  RJ70    164    11
# ..                                              ...  ...   ...    ...   ...
# 143                                   Ilyushin IL76  IL7  IL76    218     8
# 144                                   Ilyushin IL86  ILW  IL86    294     9
# 145                                   Ilyushin IL96  I93  IL96    168     7
# 146                                      Learjet 35  LRJ  LJ35    280     3
# 147                                      Learjet 60  LRJ  LJ60    102    15
# 148                          Lockheed L-188 Electra  LOE  L188    185    12
# 149                         McDonnell Douglas MD-11  M11  MD11    139     8
# 150                         McDonnell Douglas MD-81  M81  MD81    269     5
# 151                         McDonnell Douglas MD-82  M82  MD82    101    17
# 152                         McDonnell Douglas MD-83  M83  MD83    186    10
# 153                         McDonnell Douglas MD-87  M87  MD87     55    18
# 154                         McDonnell Douglas MD-88  M88  MD88     48    15
# 155                         McDonnell Douglas MD-90  M90  MD90     62    13
# 156                                      NAMC YS-11  YS1  YS11    235     5
# 157                                 Partenavia P.68  PN6   P68    284     4
# 158  Pilatus Britten-Norman BN-2A Mk III Trislander  BNT  TRIS    132     6
# 159         Pilatus Britten-Norman BN-2A/B Islander  BNI  BN2P    237    16
# 160                                   Pilatus PC-12  PL2  PC12    140     2
# 161                       Pilatus PC-6 Turbo Porter  PL6  PC6T    132     2
# 162                              Piper PA-31 Navajo  PA2  PA31     70     9
# 163                                       Saab 2000  S20  SB20     49     5
# 164                                   Saab SF340A/B  SF3  SF34     71    13
# 165                                   Shorts SD.360  SH6  SH36     73    16
# 166                                   Sikorsky S-61  S61   S61    156     3
# 167                                   Sikorsky S-76  S76   S76    138    16
# 168                          Sukhoi Superjet 100-95  SU9  SU95    241    13
# 169                                  Tupolev Tu-134  TU3  T134    293     2
# 171                                  Tupolev Tu-154  TU5  T154    195     7
# 172                                  Tupolev Tu-204  T20  T204    106     6
# 173                                 Yakovlev Yak-40  YK4  YK40    180    16
#
#      Range
# 0     2459
# 1     3925
# 2    11311
# 3    11403
# 4     3456
# 5    14827
# 6    13647
# 7    15544
# 8    15547
# 9     3299
# 10    8055
# 11   12734
# 12   15797
# 13   14798
# 14    6011
# 15   14874
# 16    5826
# 17   13094
# 18   11472
# 19    5853
# 20   10813
# 21   12138
# 22    9101
# 23   11932
# 24   12635
# 25    9992
# 26   12130
# 27    8721
# 28    8558
# 29   15970
# ..     ...
# 143   6768
# 144  14614
# 145   5509
# 146   2480
# 147   3879
# 148   8138
# 149  15442
# 150   1032
# 151  13253
# 152   3690
# 153   3103
# 154  11345
# 155   8708
# 156  10292
# 157  15942
# 158  14308
# 159   9309
# 160   8915
# 161   3940
# 162   1411
# 163  12543
# 164   2066
# 165  14086
# 166  11970
# 167   6648
# 168   2154
# 169   1619
# 171   2347
# 172   4599
# 173   7118
#
# [171 rows x 6 columns]

# %%
filtered[['IATA',  'Name', 'Seats', 'Crew', 'Range']].to_csv('planes_fil.txt', index=False, encoding='utf-8');
